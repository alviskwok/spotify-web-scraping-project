# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/yuenchitcheng/Documents/01Foundation/13-web_scraping'

# %%
os.chdir('..')

# %%
os.chdir('..')
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/Users/yuenchitcheng'

# %%
os.chdir('./Downloads')

# %%
df2020=pd.read_csv('2020(completed).csv')

# %%
df2020[df2020['singer']=='Dear Jane']
# Out:
#        Unnamed: 0                    date     song     singer  streams  \
# 5               5  2020-12-25--2021-01-01    銀河修理員  Dear Jane  96079.0
# 10             10  2020-12-25--2021-01-01  未開始已經結束  Dear Jane  83958.0
# 25             25  2020-12-25--2021-01-01    哀的美敦書  Dear Jane  60227.0
# 36             36  2020-12-25--2021-01-01     2084  Dear Jane  51631.0
# 60             60  2020-12-25--2021-01-01  哪裡只得我共你  Dear Jane  39085.0
# ...           ...                     ...      ...        ...      ...
# 10368       10368  2020-01-03--2020-01-10   永遠飛行模式  Dear Jane  24156.0
# 10495       10495  2019-12-27--2020-01-03     2084  Dear Jane  27864.0
# 10516       10516  2019-12-27--2020-01-03  哪裡只得我共你  Dear Jane  25607.0
# 10522       10522  2019-12-27--2020-01-03  不許你注定一人  Dear Jane  25032.0
# 10559       10559  2019-12-27--2020-01-03   永遠飛行模式  Dear Jane  22848.0
#
#                                                 url_list  \
# ...

# %%
df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10600 entries, 0 to 10599
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10600 non-null  int64
#  1   date        10600 non-null  object
#  2   song        10600 non-null  object
#  3   singer      10600 non-null  object
#  4   streams     10600 non-null  float64
#  5   url_list    10600 non-null  object
#  6   Company     10303 non-null  object
#  7   Duration    10600 non-null  int64
#  8   Gender      10600 non-null  object
#  9   Lang        10600 non-null  object
#  10  jane        10600 non-null  int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 911.1+ KB

# %%
df2020.drop(columns=['Unnamed: 0','jane'])
# Out:
#                          date  \
# 0      2020-12-25--2021-01-01
# 1      2020-12-25--2021-01-01
# 2      2020-12-25--2021-01-01
# 3      2020-12-25--2021-01-01
# 4      2020-12-25--2021-01-01
# ...                       ...
# 10595  2019-12-27--2020-01-03
# 10596  2019-12-27--2020-01-03
# 10597  2019-12-27--2020-01-03
# 10598  2019-12-27--2020-01-03
# 10599  2019-12-27--2020-01-03
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 10595                                          Attention
# 10596                      boyfriend (with Social House)
# 10597                                               最後晚餐
# ...

# %%
df2020.astype({'streams': int})
# Out:
#        Unnamed: 0                    date  \
# 0               0  2020-12-25--2021-01-01
# 1               1  2020-12-25--2021-01-01
# 2               2  2020-12-25--2021-01-01
# 3               3  2020-12-25--2021-01-01
# 4               4  2020-12-25--2021-01-01
# ...           ...                     ...
# 10595       10595  2019-12-27--2020-01-03
# 10596       10596  2019-12-27--2020-01-03
# 10597       10597  2019-12-27--2020-01-03
# 10598       10598  2019-12-27--2020-01-03
# 10599       10599  2019-12-27--2020-01-03
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10600 entries, 0 to 10599
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10600 non-null  int64
#  1   date        10600 non-null  object
#  2   song        10600 non-null  object
#  3   singer      10600 non-null  object
#  4   streams     10600 non-null  float64
#  5   url_list    10600 non-null  object
#  6   Company     10303 non-null  object
#  7   Duration    10600 non-null  int64
#  8   Gender      10600 non-null  object
#  9   Lang        10600 non-null  object
#  10  jane        10600 non-null  int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 911.1+ KB

# %%
df2020=df2020.drop(columns=['Unnamed: 0','jane'])

# %%
df2020=df2020.astype({'streams': int})

# %%
df2020
# Out:
#                          date  \
# 0      2020-12-25--2021-01-01
# 1      2020-12-25--2021-01-01
# 2      2020-12-25--2021-01-01
# 3      2020-12-25--2021-01-01
# 4      2020-12-25--2021-01-01
# ...                       ...
# 10595  2019-12-27--2020-01-03
# 10596  2019-12-27--2020-01-03
# 10597  2019-12-27--2020-01-03
# 10598  2019-12-27--2020-01-03
# 10599  2019-12-27--2020-01-03
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 10595                                          Attention
# 10596                      boyfriend (with Social House)
# 10597                                               最後晚餐
# ...

# %%
df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10600 entries, 0 to 10599
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      10600 non-null  object
#  1   song      10600 non-null  object
#  2   singer    10600 non-null  object
#  3   streams   10600 non-null  int64
#  4   url_list  10600 non-null  object
#  5   Company   10303 non-null  object
#  6   Duration  10600 non-null  int64
#  7   Gender    10600 non-null  object
#  8   Lang      10600 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 745.4+ KB

# %%
df2021=pd.read_csv('2021(completed).csv')

# %%
df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10600 entries, 0 to 10599
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      10600 non-null  object
#  1   song      10600 non-null  object
#  2   singer    10600 non-null  object
#  3   streams   10600 non-null  int64
#  4   url_list  10600 non-null  object
#  5   Company   10551 non-null  object
#  6   Duration  10600 non-null  int64
#  7   Gender    10600 non-null  object
#  8   Lang      10600 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 745.4+ KB

# %%
df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10600 entries, 0 to 10599
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      10600 non-null  object
#  1   song      10600 non-null  object
#  2   singer    10600 non-null  object
#  3   streams   10600 non-null  int64
#  4   url_list  10600 non-null  object
#  5   Company   10551 non-null  object
#  6   Duration  10600 non-null  int64
#  7   Gender    10600 non-null  object
#  8   Lang      10600 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 745.4+ KB

# %%
df2021
# Out:
#                          date               song     singer  streams  \
# 0      2021-12-31--2022-01-07                記憶棉     MC 張天賦   434327
# 1      2021-12-31--2022-01-07               反對無效     MC 張天賦   342240
# 2      2021-12-31--2022-01-07               時候不早     MC 張天賦   306681
# 3      2021-12-31--2022-01-07   如果可以 - 電影"月老"主題曲    WeiBird   215619
# 4      2021-12-31--2022-01-07    Dear My Friend,   Keung To   201078
# ...                       ...                ...        ...      ...
# 10595  2021-01-01--2021-01-08           あの夢をなぞって    YOASOBI    19571
# 10596  2021-01-01--2021-01-08                AYA    MAMAMOO    19529
# 10597  2021-01-01--2021-01-08  See You Next Time        AGA    19484
# 10598  2021-01-01--2021-01-08      DDU-DU DDU-DU  BLACKPINK    19408
# 10599  2021-01-01--2021-01-08               廻廻奇譚        Eve    19371
#
#                                                 url_list  \
# 0      https://open.spotify.com/track/1ZrnCyms7CBYsCv...
# ...

# %%
df2021.isnull().sum()
# Out:
# date         0
# song         0
# singer       0
# streams      0
# url_list     0
# Company     49
# Duration     0
# Gender       0
# Lang         0
# dtype: int64

# %%
df_anova_2020 = df2020[['Gender','streams']]
df_anova_2021 = df2021[['Gender','streams']]

# %%
import numpy as np
import pandas as pd
import seaborn as sb
from numpy import sqrt, abs, round
import scipy.stats as stats
from scipy.stats import norm

# %%
grps=pd.unique(df2020.Gender.values)

# %%
grps
# Out:
# array(['M', 'G', 'F'], dtype=object)

# %%
d_data = {grp:df_anova_2020['streams'][df_anova_2020.Gender == grp] for grp in grps}
F, p = stats.f_oneway(d_data['G'],d_data['F'], d_data['M'])

# %%
p
# Out:
# 3.138402944065391e-26

# %%
d_data2 = {grp:df_anova_2021['streams'][df_anova_2021.Gender == grp] for grp in grps}
F, p = stats.f_oneway(d_data2['G'], d_data2['F'], d_data2['M'])

# %%
p
# Out:
# 5.478887479071245e-58

# %%
df2020.groupby('Gender').streams.mean()
# Out:
# Gender
# F    34153.037631
# G    37218.697364
# M    32338.939234
# Name: streams, dtype: float64

# %%
df2020.groupby('Gender').streams.mean().plot(kind='bar', figsize=(9,6))
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
df2021.groupby('Gender').streams.mean()
# Out:
# Gender
# F    38677.308908
# G    42993.205613
# M    50611.880614
# Name: streams, dtype: float64

# %%
df2021.groupby('Gender').streams.mean().plot(kind='bar', figsize=(9,6))
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
can2020=df2020[df2020['Lang']=='Can']

# %%
can2020
# Out:
#                          date  \
# 0      2020-12-25--2021-01-01
# 1      2020-12-25--2021-01-01
# 2      2020-12-25--2021-01-01
# 3      2020-12-25--2021-01-01
# 4      2020-12-25--2021-01-01
# ...                       ...
# 10588  2019-12-27--2020-01-03
# 10591  2019-12-27--2020-01-03
# 10593  2019-12-27--2020-01-03
# 10597  2019-12-27--2020-01-03
# 10599  2019-12-27--2020-01-03
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 10588                                              偷情的禮儀
# 10591                                                發現號
# 10593                                               海闊天空
# ...

# %%
can2021=df2021[df2021['Lang']=='Can']

# %%
can2021
# Out:
#                          date               song         singer  streams  \
# 0      2021-12-31--2022-01-07                記憶棉         MC 張天賦   434327
# 1      2021-12-31--2022-01-07               反對無效         MC 張天賦   342240
# 2      2021-12-31--2022-01-07               時候不早         MC 張天賦   306681
# 4      2021-12-31--2022-01-07    Dear My Friend,       Keung To   201078
# 5      2021-12-31--2022-01-07            在空中的這一秒    Terence Lam   193263
# ...                       ...                ...            ...      ...
# 10587  2021-01-01--2021-01-08               長相廝守         ToNick    20229
# 10588  2021-01-01--2021-01-08                  追  Leslie Cheung    20025
# 10590  2021-01-01--2021-01-08              地球來的人       Jay Fung    19793
# 10592  2021-01-01--2021-01-08                陀飛輪     Eason Chan    19645
# 10597  2021-01-01--2021-01-08  See You Next Time            AGA    19484
#
#                                                 url_list  \
# ...

# %%
df_anova_can2020 = can2020[['Gender','streams']]

# %%
df_anova_can2021 = can2021[['Gender','streams']]

# %%
d_data_can2020 = {grp:df_anova_can2020['streams'][df_anova_can2020.Gender == grp] for grp in grps}
F, p = stats.f_oneway(d_data_can2020['G'],d_data_can2020['F'], d_data_can2020['M'])

# %%
p
# Out:
# 0.00028817551003585784

# %%
d_data_can2021 = {grp:df_anova_can2021['streams'][df_anova_can2021.Gender == grp] for grp in grps}
F, p = stats.f_oneway(d_data_can2021['G'],d_data_can2021['F'], d_data_can2021['M'])

# %%
p
# Out:
# 4.680772620937286e-74

# %%
can2020.groupby('Gender').streams.mean()
# Out:
# Gender
# F    31946.388852
# G    34520.787234
# M    32075.301026
# Name: streams, dtype: float64

# %%
can2021.groupby('Gender').streams.mean()
# Out:
# Gender
# F    37129.389831
# G    48768.227740
# M    58306.779865
# Name: streams, dtype: float64

# %%
df2020.corr()
# Out:
#            streams  Duration
# streams   1.000000 -0.123188
# Duration -0.123188  1.000000

# %%
df2021.corr()
# Out:
#            streams  Duration
# streams   1.000000  0.048519
# Duration  0.048519  1.000000

# %%
can2020.corr()
# Out:
#            streams  Duration
# streams   1.000000 -0.022893
# Duration -0.022893  1.000000

# %%
can2021.corr()
# Out:
#            streams  Duration
# streams   1.000000 -0.021885
# Duration -0.021885  1.000000

# %%
df = pd.concat([df2020,df2021])

# %%
df
# Out:
#                          date  \
# 0      2020-12-25--2021-01-01
# 1      2020-12-25--2021-01-01
# 2      2020-12-25--2021-01-01
# 3      2020-12-25--2021-01-01
# 4      2020-12-25--2021-01-01
# ...                       ...
# 10595  2021-01-01--2021-01-08
# 10596  2021-01-01--2021-01-08
# 10597  2021-01-01--2021-01-08
# 10598  2021-01-01--2021-01-08
# 10599  2021-01-01--2021-01-08
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 10595                                           あの夢をなぞって
# 10596                                                AYA
# 10597                                  See You Next Time
# ...

# %%
can = pd.concat([can2020,can2021])

# %%
can
# Out:
#                          date  \
# 0      2020-12-25--2021-01-01
# 1      2020-12-25--2021-01-01
# 2      2020-12-25--2021-01-01
# 3      2020-12-25--2021-01-01
# 4      2020-12-25--2021-01-01
# ...                       ...
# 10587  2021-01-01--2021-01-08
# 10588  2021-01-01--2021-01-08
# 10590  2021-01-01--2021-01-08
# 10592  2021-01-01--2021-01-08
# 10597  2021-01-01--2021-01-08
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 10587                                               長相廝守
# 10588                                                  追
# 10590                                              地球來的人
# ...

# %%
df.groupby('Company').streams.sum().sort_values(ascending=False)
# Out:
# Company
# Warner Music Hong Kong Ltd.                                                                                                                                                          65883505
#  Nation Records Co. Ltd.                                                                                                                                                             53888803
# Universal Music Ltd.                                                                                                                                                                 43275156
# Terence Lam Production & Co.                                                                                                                                                         37453822
# YG Entertainment, distributed through Interscope Records                                                                                                                             21779549
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(16,12))
sns.boxplot(data=df, x="Gender", y='streams')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='streams'>

# %%
plt.figure(figsize=(16,12))
sns.boxplot(data=can, x="Gender", y='streams')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='streams'>

# %%
plt.figure(figsize=(16,12))
sns.boxplot(data=df, x="Lang", y='streams')
# Out:
# <AxesSubplot:xlabel='Lang', ylabel='streams'>

# %%
df2020.groupby('Lang').streams.mean()
# Out:
# Lang
# Can      32556.894101
# Eng      35695.345976
# Man      29789.524621
# Other    39519.345018
# Name: streams, dtype: float64

# %%
df2021.groupby('Lang').streams.mean()
# Out:
# Lang
# Can      50164.787400
# Eng      39437.374958
# Man      37263.680808
# Other    37298.374297
# Name: streams, dtype: float64

# %%
df2020.groupby('singer').streams.sum().sort_values(ascending=False)
# Out:
# singer
# Dear Jane        13536077
# BLACKPINK        11715465
# Eason Chan        8965995
# BTS               8004148
# Ed Sheeran        7392459
#                    ...
# Why Don't We        18088
# Mavis Hee           17934
# Mustard             17778
# Kane Brown          17614
# Axel Thesleff       17461
# Name: streams, Length: 541, dtype: int64

# %%
df2021.groupby('singer').streams.sum().sort_values(ascending=False)
# Out:
# singer
# Terence Lam    31638161
# Dear Jane      21988050
# 陳卓賢 Ian        15470508
# Jer 柳應廷        13238839
# Edan 呂爵安       12974668
#                  ...
# iKON              21220
# LANY              21105
# Lauv              20997
# HANA              20457
# 戴祖儀               20215
# Name: streams, Length: 375, dtype: int64

# %%
df.groupby('singer').streams.sum().sort_values(ascending=False)
# Out:
# singer
# Terence Lam      37453822
# Dear Jane        35524127
# Hins Cheung      20059953
# BLACKPINK        17449556
# BTS              17035757
#                    ...
# Why Don't We        18088
# Mavis Hee           17934
# Mustard             17778
# Kane Brown          17614
# Axel Thesleff       17461
# Name: streams, Length: 730, dtype: int64

# %%
df=df.reset_index()

# %%
df
# Out:
#        index                    date  \
# 0          0  2020-12-25--2021-01-01
# 1          1  2020-12-25--2021-01-01
# 2          2  2020-12-25--2021-01-01
# 3          3  2020-12-25--2021-01-01
# 4          4  2020-12-25--2021-01-01
# ...      ...                     ...
# 21195  10595  2021-01-01--2021-01-08
# 21196  10596  2021-01-01--2021-01-08
# 21197  10597  2021-01-01--2021-01-08
# 21198  10598  2021-01-01--2021-01-08
# 21199  10599  2021-01-01--2021-01-08
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 21195                                           あの夢をなぞって
# ...

# %%
df['ranking']=df.index+1

# %%
df.ranking=df.ranking%200

# %%
df.ranking=df.ranking.replace(0,200)
df
# Out:
#        index                    date  \
# 0          0  2020-12-25--2021-01-01
# 1          1  2020-12-25--2021-01-01
# 2          2  2020-12-25--2021-01-01
# 3          3  2020-12-25--2021-01-01
# 4          4  2020-12-25--2021-01-01
# ...      ...                     ...
# 21195  10595  2021-01-01--2021-01-08
# 21196  10596  2021-01-01--2021-01-08
# 21197  10597  2021-01-01--2021-01-08
# 21198  10598  2021-01-01--2021-01-08
# 21199  10599  2021-01-01--2021-01-08
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 21195                                           あの夢をなぞって
# ...

# %%
df_new=df.copy()

# %%
df_new=df_new[df_new.ranking<11]

# %%
df_new
# Out:
#        index                    date  \
# 0          0  2020-12-25--2021-01-01
# 1          1  2020-12-25--2021-01-01
# 2          2  2020-12-25--2021-01-01
# 3          3  2020-12-25--2021-01-01
# 4          4  2020-12-25--2021-01-01
# ...      ...                     ...
# 21005  10405  2021-01-01--2021-01-08
# 21006  10406  2021-01-01--2021-01-08
# 21007  10407  2021-01-01--2021-01-08
# 21008  10408  2021-01-01--2021-01-08
# 21009  10409  2021-01-01--2021-01-08
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 21005                                              下一位前度
# ...

# %%
df2020
# Out:
#                          date  \
# 0      2020-12-25--2021-01-01
# 1      2020-12-25--2021-01-01
# 2      2020-12-25--2021-01-01
# 3      2020-12-25--2021-01-01
# 4      2020-12-25--2021-01-01
# ...                       ...
# 10595  2019-12-27--2020-01-03
# 10596  2019-12-27--2020-01-03
# 10597  2019-12-27--2020-01-03
# 10598  2019-12-27--2020-01-03
# 10599  2019-12-27--2020-01-03
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 10595                                          Attention
# 10596                      boyfriend (with Social House)
# 10597                                               最後晚餐
# ...

# %%
df2020=df2020.reset_index()

# %%
df2020['ranking']=df2020.index+1

# %%
df2020.ranking=df2020.ranking%200

# %%
df2020.ranking=df2020.ranking.replace(0,200)
df2020
# Out:
#        index                    date  \
# 0          0  2020-12-25--2021-01-01
# 1          1  2020-12-25--2021-01-01
# 2          2  2020-12-25--2021-01-01
# 3          3  2020-12-25--2021-01-01
# 4          4  2020-12-25--2021-01-01
# ...      ...                     ...
# 10595  10595  2019-12-27--2020-01-03
# 10596  10596  2019-12-27--2020-01-03
# 10597  10597  2019-12-27--2020-01-03
# 10598  10598  2019-12-27--2020-01-03
# 10599  10599  2019-12-27--2020-01-03
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 10595                                          Attention
# ...

# %%
df_new2020=df2020.copy()

# %%
df_new2020=df_new2020[df_new2020.ranking<11]

# %%
df_new2020
# Out:
#        index                    date  \
# 0          0  2020-12-25--2021-01-01
# 1          1  2020-12-25--2021-01-01
# 2          2  2020-12-25--2021-01-01
# 3          3  2020-12-25--2021-01-01
# 4          4  2020-12-25--2021-01-01
# ...      ...                     ...
# 10405  10405  2019-12-27--2020-01-03
# 10406  10406  2019-12-27--2020-01-03
# 10407  10407  2019-12-27--2020-01-03
# 10408  10408  2019-12-27--2020-01-03
# 10409  10409  2019-12-27--2020-01-03
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 10405                                everything i wanted
# ...

# %%
a=pd.unique(df_new2020.song)

# %%
a
# Out:
# array(['刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心底的名字>主題曲', '是但求其愛',
#        '一人之境 in C major', '時光倒流一句話', '隔離 - Studio Live Duet', '銀河修理員',
#        'Afterglow', 'All I Want for Christmas Is You', 'Last Christmas',
#        'Santa Tell Me', "Rockin' Around The Christmas Tree", 'willow',
#        '炎', 'Dynamite', 'Life Goes On', 'positions',
#        'Monster (Shawn Mendes & Justin Bieber)', 'Therefore I Am',
#        'Blue & Grey', 'Lovesick Girls', 'How You Like That',
#        'Ice Cream (with Selena Gomez)', "I CAN'T STOP ME",
#        'Lonely (with benny blanco)', '34+35', 'Pretty Savage',
#        'Holy (feat. Chance The Rapper)', 'Bet You Wanna (feat. Cardi B)',
#        '想見你想見你想見你(電視劇"想見你"片尾曲)', 'Crazy Over You', 'Love To Hate Me',
#        'You Never Know', '呼吸有害', '哀的美敦書', '地球上最浪漫的一首歌',
#        'Mood (feat. iann dior)', 'WAP (feat. Megan Thee Stallion)',
#        '一人之境', 'Not Shy', 'Laugh Now Cry Later (feat. Lil Durk)',
# ...

# %%
s="是但求其愛"
b=df_new[df_new['song']==s]

# %%
c=b.weeks

# %%
c
# Out:
# 1          0
# 203        1
# 400        2
# 600        3
# 800        4
# 1001       5
# 19008     95
# 19205     96
# 19404     97
# 19604     98
# 19805     99
# 20006    100
# 20207    101
# 20406    102
# 20606    103
# 20805    104
# 21006    105
# Name: weeks, dtype: int64

# %%
# Out:
# 1
# 203
# 400
# 600
# 800
# 1001
# 19008
# 19205
# 19404
# 19604
# 19805
# 20006
# 20207
# 20406
# 20606
# 20805
# 21006

# %%
df_new['weeks']=df_new.index//200

# %%
df_new
# Out:
#        index                    date  \
# 0          0  2020-12-25--2021-01-01
# 1          1  2020-12-25--2021-01-01
# 2          2  2020-12-25--2021-01-01
# 3          3  2020-12-25--2021-01-01
# 4          4  2020-12-25--2021-01-01
# ...      ...                     ...
# 21005  10405  2021-01-01--2021-01-08
# 21006  10406  2021-01-01--2021-01-08
# 21007  10407  2021-01-01--2021-01-08
# 21008  10408  2021-01-01--2021-01-08
# 21009  10409  2021-01-01--2021-01-08
#
#                                                     song  \
# 0      刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 1                                                  是但求其愛
# 2                                        一人之境 in C major
# 3                                                時光倒流一句話
# 4                                  隔離 - Studio Live Duet
# ...                                                  ...
# 21005                                              下一位前度
# ...

# %%
a=pd.unique(df_new2020.song)
counting=[]
for i in a:


    b=df_new[df_new['song']==i]
    c=b.weeks
    count=0

    for j in c:
        if j<c.values[0]+52:
            count+=1
    counting.append(count)
mean_weeks=(sum(counting)/len(counting))
mean_weeks
# Out:
# 5.145631067961165

# %%
df_new.streams.mean()
# Out:
# 119396.35094339623

# %%
x=mean_weeks*df_new.streams.mean()
x
# Out:
# 614369.5728155341
